# %% [markdown]
# # Year in Review
#
# Pulls from `MARTS.fct_daily_listening`, `MARTS.fct_daily_activity`, `MARTS.fct_daily_coding` to assemble a one-page personal annual report.
#
# **TODO**: implement once marts are populated. Sections below are placeholders for the final report.

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from snowflake.connector import connect
from dotenv import load_dotenv

load_dotenv()
sns.set_theme(style='whitegrid')

# %%
# TODO: connect to Snowflake and pull marts
# conn = connect(
#     account=os.environ['SNOWFLAKE_ACCOUNT'],
#     user=os.environ['SNOWFLAKE_USER'],
#     password=os.environ['SNOWFLAKE_PASSWORD'],
#     warehouse=os.environ['SNOWFLAKE_WAREHOUSE'],
#     database=os.environ['SNOWFLAKE_DATABASE'],
#     schema='MARTS',
# )
# listening = pd.read_sql('select * from fct_daily_listening where listen_date >= dateadd(year, -1, current_date)', conn)

# %% [markdown]
# ## 🎧 Listening
# - Total minutes listened
# - Top 10 artists by play count
# - Listening time-of-day heatmap
# - Discovery rate (new artists per month)

# %% [markdown]
# ## 🏃 Activity
# - Total distance + elevation gain
# - Weekly volume trend
# - Activity-type breakdown

# %% [markdown]
# ## 💻 Coding
# - Commits per week
# - Repo / language diversity
# - Longest streak

# %% [markdown]
# ## 📅 Calendar
# - Meeting hours per week
# - Focus-block share
